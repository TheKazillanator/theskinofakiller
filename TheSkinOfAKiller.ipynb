# %% [markdown]
# ## Background
#
#
# ### Sort exchange vs not exchange?
# What level of granularity to start at?
# - conversation until end = exchange
# - subparts are lines/quotes etc
# - want informational density and quantity of both
# - length of exchange and density per segment
#
# Idk what ml to use for that for now.
#
# ### For classifying exchanges based on participants
# _https://blog.paperspace.com/text-classification-with-deep-learning/#rnn-based-models_
#
# There are many machine learning methods for parsing text. You need one that is _not_ for binary classification, but for sorting into multiple categories.
# - RNN = recurrent neural network: good at understanding long-range semantics like part of speech tagging
# - CNN = better at understanding local vs location independent patterns, like key phrases expressing a particular sentiment
# - Transformer architectures are the most state of the art right now tho
#
# However. For just classifying participants, we can use TF-IDF (Term Frequency * Inverse Document Frequency), which turns words into numbers. Now we have a giant vector of vocabulary and how important it is.
# - SVM: learns a separating hyperplane. Ie will separate out conversations in n-dimensional conversation space.
# - Linear svm recommended.

# %%
## Package Imports

# %% [markdown]
# Import Pre-trained NN

# %% [markdown]
# Test NN

# %% [markdown]
# Retrain NN/Refine Results

# %% [markdown]
# Useful Metrics
